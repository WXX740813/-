# %% [markdown]
# mmsegmenttaion训练过程

# %%
# 进入主目录
import os
os.chdir(r'F:\NE\flood shiliang\vad\mmsegmentation-1.1.2')

# %%
# 开始训练
# !python tools/train.py Zihao-Configs/ZihaoDataset_KNet_20230818.py
# Out:
# 01/03 12:01:01 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: win32
#     Python: 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
#     CUDA available: True
#     numpy_random_seed: 0
#     GPU 0: NVIDIA GeForce RTX 3070 Ti
#     CUDA_HOME: C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.3
#     NVCC: Cuda compilation tools, release 11.3, V11.3.58
#     MSVC: ?? x64 ? Microsoft (R) C/C++ ????? 19.29.30140 ?
#     GCC: n/a
#     PyTorch: 1.10.1+cu113
#     PyTorch compiling details: PyTorch built with:
#   - C++ Version: 199711
#   - MSVC 192829337
#   - Intel(R) Math Kernel Library Version 2020.0.2 Product Build 20200624 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.2.3 (Git Hash 7336ca9f055cf1bfa13efb658fe15dc9b41f0740)
#   - OpenMP 2019
#   - LAPACK is enabled (usually provided by MKL)
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.3
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_61,code=sm_61;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_37,code=compute_37
#   - CuDNN 8.2
#   - Magma 2.5.4
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.3, CUDNN_VERSION=8.2.0, CXX_COMPILER=C:/w/b/windows/tmp_bin/sccache-cl.exe, CXX_FLAGS=/DWIN32 /D_WINDOWS /GR /EHsc /w /bigobj -DUSE_PTHREADPOOL -openmp:experimental -IC:/w/b/windows/mkl/include -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOCUPTI -DUSE_FBGEMM -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.10.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=OFF, USE_NNPACK=OFF, USE_OPENMP=ON,
#
#     TorchVision: 0.11.2+cu113
#     OpenCV: 4.7.0
#     MMEngine: 0.8.4
#
# Runtime environment:
#     cudnn_benchmark: True
#     dist_cfg: {'backend': 'nccl'}
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     seed: 0
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 01/03 12:01:02 - mmengine - INFO - Config:
# checkpoint_file = 'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_large_patch4_window7_224_22k_20220308-d5bdebaf.pth'
# conv_kernel_size = 1
# crop_size = (
#     512,
#     512,
# )
# data_preprocessor = dict(
#     bgr_to_rgb=True,
#     mean=[
#         123.675,
#         116.28,
#         103.53,
#     ],
#     pad_val=0,
#     seg_pad_val=255,
#     size=(
#         512,
#         512,
#     ),
#     std=[
#         58.395,
#         57.12,
#         57.375,
#     ],
#     type='SegDataPreProcessor')
# data_root = 'labelme2marsk/'
# dataset_type = 'ZihaoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         by_epoch=False,
#         interval=100,
#         max_keep_ckpts=2,
#         save_best='mIoU',
#         type='CheckpointHook'),
#     logger=dict(interval=100, log_metric_by_epoch=False, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='SegVisualizationHook'))
# default_scope = 'mmseg'
# env_cfg = dict(
#     cudnn_benchmark=True,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# img_ratios = [
#     0.5,
#     0.75,
#     1.0,
#     1.25,
#     1.5,
#     1.75,
# ]
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# model = dict(
#     auxiliary_head=dict(
#         align_corners=False,
#         channels=256,
#         concat_input=False,
#         dropout_ratio=0.1,
#         in_channels=768,
#         in_index=2,
#         loss_decode=dict(
#             loss_weight=0.4, type='CrossEntropyLoss', use_sigmoid=False),
#         norm_cfg=dict(requires_grad=True, type='SyncBN'),
#         num_classes=6,
#         num_convs=1,
#         type='FCNHead'),
#     backbone=dict(
#         attn_drop_rate=0.0,
#         depths=[
#             2,
#             2,
#             18,
#             2,
#         ],
#         drop_path_rate=0.3,
#         drop_rate=0.0,
#         embed_dims=192,
#         mlp_ratio=4,
#         num_heads=[
#             6,
#             12,
#             24,
#             48,
#         ],
#         out_indices=(
#             0,
#             1,
#             2,
#             3,
#         ),
#         patch_norm=True,
#         qk_scale=None,
# f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\backbones\swin.py:556: UserWarning: DeprecationWarning: pretrained is deprecated, please use "init_cfg" instead
#   warnings.warn('DeprecationWarning: pretrained is deprecated, '
# f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\builder.py:36: UserWarning: ``build_loss`` would be deprecated soon, please use ``mmseg.registry.MODELS.build()``
#   warnings.warn('``build_loss`` would be deprecated soon, please use '
# f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\losses\cross_entropy_loss.py:235: UserWarning: Default ``avg_non_ignore`` is False, if you would like to ignore the certain label and average loss over non-ignore labels, which is the same with PyTorch official cross_entropy, set ``avg_non_ignore=True``.
#   warnings.warn(
# f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\engine\hooks\visualization_hook.py:61: UserWarning: The draw is False, it means that the hook for visualization will not take effect. The results will NOT be visualized or stored.
#   warnings.warn('The draw is False, it means that the '
# Traceback (most recent call last):
#   File "F:\NE\flood shiliang\vad\mmsegmentation-1.1.2\tools\train.py", line 104, in <module>
#     main()
#   File "F:\NE\flood shiliang\vad\mmsegmentation-1.1.2\tools\train.py", line 100, in main
#     runner.train()
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\mmengine\runner\runner.py", line 1745, in train
#     model = self.train_loop.run()  # type: ignore
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\mmengine\runner\loops.py", line 278, in run
#     self.run_iter(data_batch)
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\mmengine\runner\loops.py", line 301, in run_iter
#     outputs = self.runner.model.train_step(
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\mmengine\model\base_model\base_model.py", line 114, in train_step
#     losses = self._run_forward(data, mode='loss')  # type: ignore
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\mmengine\model\base_model\base_model.py", line 340, in _run_forward
#     results = self(**data, mode=mode)
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\torch\nn\modules\module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\segmentors\base.py", line 94, in forward
#     return self.loss(inputs, data_samples)
#   File "f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\segmentors\encoder_decoder.py", line 178, in loss
#     loss_decode = self._decode_head_forward_train(x, data_samples)
#   File "f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\segmentors\encoder_decoder.py", line 139, in _decode_head_forward_train
#     loss_decode = self.decode_head.loss(inputs, data_samples,
#   File "f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\decode_heads\decode_head.py", line 261, in loss
#     seg_logits = self.forward(inputs)
#   File "f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\decode_heads\knet_head.py", line 435, in forward
#     feats = self.kernel_generate_head._forward_feature(inputs)
#   File "f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\decode_heads\uper_head.py", line 105, in _forward_feature
#     laterals.append(self.psp_forward(inputs))
#   File "f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\decode_heads\uper_head.py", line 80, in psp_forward
#     psp_outs.extend(self.psp_modules(x))
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\torch\nn\modules\module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "f:\ne\flood shiliang\vad\mmsegmentation-1.1.2\mmseg\models\decode_heads\psp_head.py", line 52, in forward
#     ppm_out = ppm(x)
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\torch\nn\modules\module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\torch\nn\modules\container.py", line 141, in forward
#     input = module(input)
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\torch\nn\modules\module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\mmcv\cnn\bricks\conv_module.py", line 209, in forward
#     x = self.norm(x)
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\torch\nn\modules\module.py", line 1102, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\torch\nn\modules\batchnorm.py", line 168, in forward
#     return F.batch_norm(
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\torch\nn\functional.py", line 2280, in batch_norm
#     _verify_batch_size(input.size())
#   File "D:\zhuangzaidizhi\anaconda\anda\lib\site-packages\torch\nn\functional.py", line 2248, in _verify_batch_size
#     raise ValueError("Expected more than 1 value per channel when training, got input size {}".format(size))
# ValueError: Expected more than 1 value per channel when training, got input size torch.Size([1, 512, 1, 1])
#         qkv_bias=True,
#         type='SwinTransformer',
#         use_abs_pos_embed=False,
#         window_size=7),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_val=0,
#         seg_pad_val=255,
#         size=(
#             512,
#             512,
#         ),
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='SegDataPreProcessor'),
#     decode_head=dict(
#         kernel_generate_head=dict(
#             align_corners=False,
#             channels=512,
#             dropout_ratio=0.1,
#             in_channels=[
#                 192,
#                 384,
#                 768,
#                 1536,
#             ],
#             in_index=[
#                 0,
#                 1,
#                 2,
#                 3,
#             ],
#             loss_decode=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=False),
#             norm_cfg=dict(requires_grad=True, type='SyncBN'),
#             num_classes=6,
#             pool_scales=(
#                 1,
#                 2,
#                 3,
#                 6,
#             ),
#             type='UPerHead'),
#         kernel_update_head=[
#             dict(
#                 conv_kernel_size=1,
#                 dropout=0.0,
#                 feat_transform_cfg=dict(
#                     act_cfg=None, conv_cfg=dict(type='Conv2d')),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=512,
#                 kernel_updator_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=256,
#                     in_channels=256,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='KernelUpdator'),
#                 num_classes=150,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_mask_fcs=1,
#                 out_channels=512,
#                 type='KernelUpdateHead',
#                 with_ffn=True),
#             dict(
#                 conv_kernel_size=1,
#                 dropout=0.0,
#                 feat_transform_cfg=dict(
#                     act_cfg=None, conv_cfg=dict(type='Conv2d')),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=512,
#                 kernel_updator_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=256,
#                     in_channels=256,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='KernelUpdator'),
#                 num_classes=150,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_mask_fcs=1,
#                 out_channels=512,
#                 type='KernelUpdateHead',
#                 with_ffn=True),
#             dict(
#                 conv_kernel_size=1,
#                 dropout=0.0,
#                 feat_transform_cfg=dict(
#                     act_cfg=None, conv_cfg=dict(type='Conv2d')),
#                 feedforward_channels=2048,
#                 ffn_act_cfg=dict(inplace=True, type='ReLU'),
#                 in_channels=512,
#                 kernel_updator_cfg=dict(
#                     act_cfg=dict(inplace=True, type='ReLU'),
#                     feat_channels=256,
#                     in_channels=256,
#                     norm_cfg=dict(type='LN'),
#                     out_channels=256,
#                     type='KernelUpdator'),
#                 num_classes=150,
#                 num_ffn_fcs=2,
#                 num_heads=8,
#                 num_mask_fcs=1,
#                 out_channels=512,
#                 type='KernelUpdateHead',
#                 with_ffn=True),
#         ],
#         num_stages=3,
#         type='IterativeDecodeHead'),
#     pretrained=
#     'https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_large_patch4_window7_224_22k_20220308-d5bdebaf.pth',
#     test_cfg=dict(mode='whole'),
#     train_cfg=dict(),
#     type='EncoderDecoder')
# norm_cfg = dict(requires_grad=True, type='BN')
# num_stages = 3
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=1, norm_type=2),
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=6e-05, type='AdamW', weight_decay=0.0005),
#     paramwise_cfg=dict(
#         custom_keys=dict(
#             absolute_pos_embed=dict(decay_mult=0.0),
#             norm=dict(decay_mult=0.0),
#             relative_position_bias_table=dict(decay_mult=0.0))),
#     type='OptimWrapper')
# optimizer = dict(lr=0.01, momentum=0.9, type='SGD', weight_decay=0.0005)
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1000, start_factor=0.001,
#         type='LinearLR'),
#     dict(
#         begin=1000,
#         by_epoch=False,
#         end=80000,
#         milestones=[
#             60000,
#             72000,
#         ],
#         type='MultiStepLR'),
# ]
# randomness = dict(seed=0)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         data_root='labelme2marsk/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='ZihaoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ], type='IoUMetric')
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         2048,
#         1024,
#     ), type='Resize'),
#     dict(type='LoadAnnotations'),
#     dict(type='PackSegInputs'),
# ]
# train_cfg = dict(max_iters=1000, type='IterBasedTrainLoop', val_interval=100)
# train_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(
#             img_path='img_dir/train', seg_map_path='ann_dir/train'),
#         data_root='labelme2marsk/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations'),
#             dict(
#                 keep_ratio=True,
#                 ratio_range=(
#                     0.5,
#                     2.0,
#                 ),
#                 scale=(
#                     2048,
#                     1024,
#                 ),
#                 type='RandomResize'),
#             dict(
#                 cat_max_ratio=0.75, crop_size=(
#                     512,
#                     512,
#                 ), type='RandomCrop'),
#             dict(prob=0.5, type='RandomFlip'),
#             dict(type='PhotoMetricDistortion'),
#             dict(type='PackSegInputs'),
#         ],
#         type='ZihaoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations'),
#     dict(
#         keep_ratio=True,
#         ratio_range=(
#             0.5,
#             2.0,
#         ),
#         scale=(
#             2048,
#             1024,
#         ),
#         type='RandomResize'),
#     dict(cat_max_ratio=0.75, crop_size=(
#         512,
#         512,
#     ), type='RandomCrop'),
#     dict(prob=0.5, type='RandomFlip'),
#     dict(type='PhotoMetricDistortion'),
#     dict(type='PackSegInputs'),
# ]
# tta_model = dict(type='SegTTAModel')
# tta_pipeline = [
#     dict(file_client_args=dict(backend='disk'), type='LoadImageFromFile'),
#     dict(
#         transforms=[
#             [
#                 dict(keep_ratio=True, scale_factor=0.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=0.75, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.0, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.25, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.5, type='Resize'),
#                 dict(keep_ratio=True, scale_factor=1.75, type='Resize'),
#             ],
#             [
#                 dict(direction='horizontal', prob=0.0, type='RandomFlip'),
#                 dict(direction='horizontal', prob=1.0, type='RandomFlip'),
#             ],
#             [
#                 dict(type='LoadAnnotations'),
#             ],
#             [
#                 dict(type='PackSegInputs'),
#             ],
#         ],
#         type='TestTimeAug'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         data_prefix=dict(img_path='img_dir/val', seg_map_path='ann_dir/val'),
#         data_root='labelme2marsk/',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 2048,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations'),
#             dict(type='PackSegInputs'),
#         ],
#         type='ZihaoDataset'),
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     iou_metrics=[
#         'mIoU',
#         'mDice',
#         'mFscore',
#     ], type='IoUMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='SegLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/ZihaoDataset-KNet'
#
# 01/03 12:01:05 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 01/03 12:01:05 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SegVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.patch_embed.norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.0.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.blocks.1.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.0.downsample.norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.0.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.blocks.1.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.1.downsample.norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.0.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.1.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.2.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.3.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.4.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.5.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.6.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.7.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.8.norm2.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm1.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.attn.w_msa.relative_position_bias_table:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.attn.w_msa.relative_position_bias_table:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.attn.w_msa.relative_position_bias_table:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- backbone.stages.2.blocks.9.norm2.weight:lr=6e-05
# ...
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.norm_out.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.norm_out.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.norm_out.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.norm_out.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.norm_out.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.norm_out.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_in.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_in.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_in.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_in.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_in.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_in.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_out.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_out.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_out.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_out.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_out.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.input_norm_out.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.fc_norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.fc_norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.fc_norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.fc_norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.fc_norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.kernel_update_conv.fc_norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.ffn_norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.ffn_norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.ffn_norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.ffn_norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.ffn_norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.0.ffn_norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.attention_norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.attention_norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.attention_norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.attention_norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.attention_norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.attention_norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_in.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_in.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_in.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_in.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_in.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_in.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_out.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_out.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_out.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_out.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_out.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.norm_out.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_in.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_in.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_in.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_in.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_in.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_in.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_out.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_out.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_out.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_out.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_out.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.input_norm_out.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.fc_norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.fc_norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.fc_norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.fc_norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.fc_norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.kernel_update_conv.fc_norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.ffn_norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.ffn_norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.ffn_norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.ffn_norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.ffn_norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.1.ffn_norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.attention_norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.attention_norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.attention_norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.attention_norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.attention_norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.attention_norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_in.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_in.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_in.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_in.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_in.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_in.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_out.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_out.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_out.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_out.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_out.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.norm_out.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_in.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_in.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_in.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_in.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_in.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_in.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_out.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_out.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_out.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_out.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_out.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.input_norm_out.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.fc_norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.fc_norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.fc_norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.fc_norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.fc_norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.kernel_update_conv.fc_norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.ffn_norm.weight:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.ffn_norm.weight:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.ffn_norm.weight:decay_mult=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.ffn_norm.bias:lr=6e-05
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.ffn_norm.bias:weight_decay=0.0
# 01/03 12:01:08 - mmengine - INFO - paramwise_options -- decode_head.kernel_update_head.2.ffn_norm.bias:decay_mult=0.0
# 01/03 12:01:08 - mmengine - WARNING - The prefix is not set in metric class IoUMetric.
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmsegmentation/v0.5/pretrain/swin/swin_large_patch4_window7_224_22k_20220308-d5bdebaf.pth
# 01/03 12:01:10 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 01/03 12:01:10 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 01/03 12:01:10 - mmengine - INFO - Checkpoints will be saved to F:\NE\flood shiliang\vad\mmsegmentation-1.1.2\work_dirs\ZihaoDataset-KNet.
